# %%
from ax.service.ax_client import AxClient, ObjectiveProperties 
from ax.utils.measurement.synthetic_functions import hartmann6 # function to optimize
from ax.utils.notebook.plotting import init_notebook_plotting, render

# %%
ax_client = AxClient()

# experiment requires a "search space" (parameters and parameter constraints) and an "optimization configuration" (objective and outcome constraints)
ax_client.create_experiment(
    name="Hartmann6 experiment",

    # search space
    parameters=[
        {
            "name": "x1",
            "type": "range",
            "bounds": [0.0, 1.0],
            "value_type": "float",  # Optional, defaults to inference from type of "bounds".
            "log_scale": False,  # Optional, defaults to False.
        },
        {
            "name": "x2",
            "type": "range",
            "bounds": [0.0, 1.0],
            "value_type": "float",
        },
        {
            "name": "x3",
            "type": "range",
            "bounds": [0.0, 1.0],
            "value_type": "float",
        },
        {
            "name": "x4",
            "type": "range",
            "bounds": [0.0, 1.0],
            "value_type": "float",
        },
        {
            "name": "x5",
            "type": "range",
            "bounds": [0.0, 1.0],
            "value_type": "float",
        },
        {
            "name": "x6",
            "type": "range",
            "bounds": [0.0, 1.0],
            "value_type": "float",
        },
    ],

    #optimization configuration
    objectives={
        "hartmann6" : ObjectiveProperties(minimize=True)
    },
    parameter_constraints=["x1 + x2 <= 2.0"],  # Optional.
    outcome_constraints=["l2norm <= 1.25"],  # Optional.
)
# Out:
# [INFO 08-20 00:24:40] ax.generation_strategy.dispatch_utils: Using Generators.BOTORCH_MODULAR since there is at least one ordered parameter and there are no unordered categorical parameters.
# [INFO 08-20 00:24:40] ax.generation_strategy.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+BoTorch', steps=[Sobol for 12 trials, BoTorch for subsequent trials]). Iterations after 12 will take longer to generate due to model-fitting.

# %%
import numpy as np

# dummy evaluation function, returns output of harmann6 and l2norm
# takes experiment parameters as input
def evaluate(parameterization):
    x = np.array([parameterization.get(f"x{i+1}") for i in range(6)])

    # return mean value and standard error of mean (uncertainity)
    return {"hartmann6" : (hartmann6(x), 0.0), "l2norm" : (np.sqrt((x**2).sum()), 0.0)}

# %%
# optimization loop
n = 25
for i in range(n):
    parameterization, trial_index = ax_client.get_next_trial() # query client for new trial
    ax_client.complete_trial(trial_index=trial_index, raw_data=evaluate(parameterization)) # submit evaluation of new trial back to the client
# Out:
# [INFO 08-20 00:24:40] ax.service.ax_client: Generated new trial 0 with parameters {'x1': 0.155389, 'x2': 0.240024, 'x3': 0.756256, 'x4': 0.059617, 'x5': 0.785997, 'x6': 0.792401} using model Sobol.
# [INFO 08-20 00:24:40] ax.service.ax_client: Completed trial 0 with data: {'hartmann6': (-0.385802, 0.0), 'l2norm': (1.379466, 0.0)}.
# [INFO 08-20 00:24:40] ax.service.ax_client: Generated new trial 1 with parameters {'x1': 0.626774, 'x2': 0.625707, 'x3': 0.205438, 'x4': 0.82324, 'x5': 0.342676, 'x6': 0.153771} using model Sobol.
# [INFO 08-20 00:24:40] ax.service.ax_client: Completed trial 1 with data: {'hartmann6': (-0.359568, 0.0), 'l2norm': (1.282715, 0.0)}.
# [INFO 08-20 00:24:40] ax.service.ax_client: Generated new trial 2 with parameters {'x1': 0.789609, 'x2': 0.274704, 'x3': 0.520386, 'x4': 0.391232, 'x5': 0.151348, 'x6': 0.362064} using model Sobol.
# [INFO 08-20 00:24:40] ax.service.ax_client: Completed trial 2 with data: {'hartmann6': (-0.314972, 0.0), 'l2norm': (1.129958, 0.0)}.
# [INFO 08-20 00:24:40] ax.service.ax_client: Generated new trial 3 with parameters {'x1': 0.30298, 'x2': 0.855691, 'x3': 0.438317, 'x4': 0.726, 'x5': 0.719486, 'x6': 0.692252} using model Sobol.
# [INFO 08-20 00:24:40] ax.service.ax_client: Completed trial 3 with data: {'hartmann6': (-0.030741, 0.0), 'l2norm': (1.593761, 0.0)}.
# [INFO 08-20 00:24:40] ax.service.ax_client: Generated new trial 4 with parameters {'x1': 0.454091, 'x2': 0.38451, 'x3': 0.020358, 'x4': 0.54519, 'x5': 0.537089, 'x6': 0.983277} using model Sobol.
# [INFO 08-20 00:24:40] ax.service.ax_client: Completed trial 4 with data: {'hartmann6': (-0.161939, 0.0), 'l2norm': (1.380939, 0.0)}.
# [INFO 08-20 00:24:40] ax.service.ax_client: Generated new trial 5 with parameters {'x1': 0.951363, 'x2': 0.996877, 'x3': 0.93841, 'x4': 0.337608, 'x5': 0.093509, 'x6': 0.086904} using model Sobol.
# [INFO 08-20 00:24:40] ax.service.ax_client: Completed trial 5 with data: {'hartmann6': (-0.010795, 0.0), 'l2norm': (1.705797, 0.0)}.
# [INFO 08-20 00:24:40] ax.service.ax_client: Generated new trial 6 with parameters {'x1': 0.601, 'x2': 0.098877, 'x3': 0.256167, 'x4': 0.878744, 'x5': 0.402207, 'x6': 0.428999} using model Sobol.
# [INFO 08-20 00:24:40] ax.service.ax_client: Completed trial 6 with data: {'hartmann6': (-0.034272, 0.0), 'l2norm': (1.246836, 0.0)}.
# [INFO 08-20 00:24:40] ax.service.ax_client: Generated new trial 7 with parameters {'x1': 0.118787, 'x2': 0.515923, 'x3': 0.70547, 'x4': 0.23843, 'x5': 0.970605, 'x6': 0.501307} using model Sobol.
# [INFO 08-20 00:24:40] ax.service.ax_client: Completed trial 7 with data: {'hartmann6': (-0.368634, 0.0), 'l2norm': (1.424151, 0.0)}.
# [INFO 08-20 00:24:40] ax.service.ax_client: Generated new trial 8 with parameters {'x1': 0.058801, 'x2': 0.322344, 'x3': 0.355839, 'x4': 0.25967, 'x5': 0.294152, 'x6': 0.655294} using model Sobol.
# [INFO 08-20 00:24:40] ax.service.ax_client: Completed trial 8 with data: {'hartmann6': (-2.639563, 0.0), 'l2norm': (0.904074, 0.0)}.
# [INFO 08-20 00:24:41] ax.service.ax_client: Generated new trial 9 with parameters {'x1': 0.534154, 'x2': 0.811911, 'x3': 0.68002, 'x4': 0.623128, 'x5': 0.835007, 'x6': 0.290132} using model Sobol.
# [INFO 08-20 00:24:41] ax.service.ax_client: Completed trial 9 with data: {'hartmann6': (-0.884656, 0.0), 'l2norm': (1.605194, 0.0)}.
# [INFO 08-20 00:24:41] ax.service.ax_client: Generated new trial 10 with parameters {'x1': 0.88638, 'x2': 0.162688, 'x3': 0.123936, 'x4': 0.160606, 'x5': 0.643618, 'x6': 0.194025} using model Sobol.
# [INFO 08-20 00:24:41] ax.service.ax_client: Completed trial 10 with data: {'hartmann6': (-0.015839, 0.0), 'l2norm': (1.142445, 0.0)}.
# [INFO 08-20 00:24:41] ax.service.ax_client: Generated new trial 11 with parameters {'x1': 0.395905, 'x2': 0.706934, 'x3': 0.916867, 'x4': 0.956567, 'x5': 0.227702, 'x6': 0.86006} using model Sobol.
# [INFO 08-20 00:24:41] ax.service.ax_client: Completed trial 11 with data: {'hartmann6': (-0.293677, 0.0), 'l2norm': (1.789892, 0.0)}.
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# [INFO 08-20 00:24:44] ax.service.ax_client: Generated new trial 12 with parameters {'x1': 0.006929, 'x2': 0.24136, 'x3': 0.296439, 'x4': 0.169111, 'x5': 0.221613, 'x6': 0.637972} using model BoTorch.
# [INFO 08-20 00:24:44] ax.service.ax_client: Completed trial 12 with data: {'hartmann6': (-2.025387, 0.0), 'l2norm': (0.794291, 0.0)}.
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# [INFO 08-20 00:24:51] ax.service.ax_client: Generated new trial 13 with parameters {'x1': 0.0, 'x2': 0.532401, 'x3': 0.499945, 'x4': 0.286442, 'x5': 0.346933, 'x6': 0.539667} using model BoTorch.
# [INFO 08-20 00:24:51] ax.service.ax_client: Completed trial 13 with data: {'hartmann6': (-1.519142, 0.0), 'l2norm': (1.013434, 0.0)}.
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# [INFO 08-20 00:24:58] ax.service.ax_client: Generated new trial 14 with parameters {'x1': 0.098752, 'x2': 0.092031, 'x3': 0.366377, 'x4': 0.293952, 'x5': 0.258735, 'x6': 0.900309} using model BoTorch.
# [INFO 08-20 00:24:58] ax.service.ax_client: Completed trial 14 with data: {'hartmann6': (-1.852645, 0.0), 'l2norm': (1.05658, 0.0)}.
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# [INFO 08-20 00:25:04] ax.service.ax_client: Generated new trial 15 with parameters {'x1': 0.139796, 'x2': 0.390378, 'x3': 0.361119, 'x4': 0.182782, 'x5': 0.343259, 'x6': 0.684087} using model BoTorch.
# [INFO 08-20 00:25:04] ax.service.ax_client: Completed trial 15 with data: {'hartmann6': (-2.314878, 0.0), 'l2norm': (0.959977, 0.0)}.
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# [INFO 08-20 00:25:10] ax.service.ax_client: Generated new trial 16 with parameters {'x1': 0.0, 'x2': 0.57259, 'x3': 0.340916, 'x4': 0.303688, 'x5': 0.419612, 'x6': 0.613118} using model BoTorch.
# [INFO 08-20 00:25:10] ax.service.ax_client: Completed trial 16 with data: {'hartmann6': (-1.177592, 0.0), 'l2norm': (1.043215, 0.0)}.
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# [INFO 08-20 00:25:16] ax.service.ax_client: Generated new trial 17 with parameters {'x1': 0.094966, 'x2': 0.316799, 'x3': 0.385819, 'x4': 0.488469, 'x5': 0.271201, 'x6': 0.593811} using model BoTorch.
# [INFO 08-20 00:25:16] ax.service.ax_client: Completed trial 17 with data: {'hartmann6': (-1.760926, 0.0), 'l2norm': (0.960728, 0.0)}.
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# [INFO 08-20 00:25:21] ax.service.ax_client: Generated new trial 18 with parameters {'x1': 0.136098, 'x2': 0.322389, 'x3': 0.388958, 'x4': 0.284099, 'x5': 0.205688, 'x6': 0.849228} using model BoTorch.
# [INFO 08-20 00:25:21] ax.service.ax_client: Completed trial 18 with data: {'hartmann6': (-1.840523, 0.0), 'l2norm': (1.057334, 0.0)}.
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# [INFO 08-20 00:25:24] ax.service.ax_client: Generated new trial 19 with parameters {'x1': 0.0, 'x2': 0.305023, 'x3': 0.211781, 'x4': 0.257297, 'x5': 0.309362, 'x6': 0.927798} using model BoTorch.
# [INFO 08-20 00:25:24] ax.service.ax_client: Completed trial 19 with data: {'hartmann6': (-1.303605, 0.0), 'l2norm': (1.077314, 0.0)}.
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# [INFO 08-20 00:25:30] ax.service.ax_client: Generated new trial 20 with parameters {'x1': 0.077412, 'x2': 0.0, 'x3': 0.420537, 'x4': 0.265248, 'x5': 0.287024, 'x6': 0.712853} using model BoTorch.
# [INFO 08-20 00:25:30] ax.service.ax_client: Completed trial 20 with data: {'hartmann6': (-2.775542, 0.0), 'l2norm': (0.918555, 0.0)}.
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# [INFO 08-20 00:25:34] ax.service.ax_client: Generated new trial 21 with parameters {'x1': 0.0, 'x2': 0.051341, 'x3': 0.261627, 'x4': 0.652233, 'x5': 0.94367, 'x6': 0.0} using model BoTorch.
# [INFO 08-20 00:25:34] ax.service.ax_client: Completed trial 21 with data: {'hartmann6': (-0.003356, 0.0), 'l2norm': (1.177711, 0.0)}.
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# [INFO 08-20 00:25:39] ax.service.ax_client: Generated new trial 22 with parameters {'x1': 0.527193, 'x2': 0.0, 'x3': 0.323067, 'x4': 0.280836, 'x5': 0.283876, 'x6': 0.712035} using model BoTorch.
# [INFO 08-20 00:25:39] ax.service.ax_client: Completed trial 22 with data: {'hartmann6': (-2.130841, 0.0), 'l2norm': (1.024086, 0.0)}.
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# [INFO 08-20 00:25:44] ax.service.ax_client: Generated new trial 23 with parameters {'x1': 0.0, 'x2': 0.626532, 'x3': 0.619663, 'x4': 0.261715, 'x5': 0.283496, 'x6': 0.728345} using model BoTorch.
# [INFO 08-20 00:25:44] ax.service.ax_client: Completed trial 23 with data: {'hartmann6': (-1.227124, 0.0), 'l2norm': (1.206596, 0.0)}.
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# /home/wtl04/coding/snapsend/computer_vision/venv310/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:150: NumericalWarning:
#
# Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#
# [INFO 08-20 00:25:50] ax.service.ax_client: Generated new trial 24 with parameters {'x1': 0.0, 'x2': 0.0, 'x3': 0.395342, 'x4': 0.227717, 'x5': 0.284247, 'x6': 0.686062} using model BoTorch.
# [INFO 08-20 00:25:50] ax.service.ax_client: Completed trial 24 with data: {'hartmann6': (-2.483414, 0.0), 'l2norm': (0.871567, 0.0)}.

# %%
ax_client.get_max_parallelism() # (num of trials, max parallelism)
# example [(12, 12), (-1, 3)]: "the max parallelism is 12 for the first 12 trials and 3 for all subsequent trials"
# Out:
# [(12, 12), (-1, 3)]

# %%
ax_client.get_trials_data_frame()
# Out:
#     trial_index arm_name trial_status   generation_node    l2norm  hartmann6  \
# 0             0      0_0    COMPLETED  GenerationStep_0  1.379466  -0.385802
# 1             1      1_0    COMPLETED  GenerationStep_0  1.282715  -0.359568
# 2             2      2_0    COMPLETED  GenerationStep_0  1.129958  -0.314972
# 3             3      3_0    COMPLETED  GenerationStep_0  1.593761  -0.030741
# 4             4      4_0    COMPLETED  GenerationStep_0  1.380939  -0.161939
# 5             5      5_0    COMPLETED  GenerationStep_0  1.705797  -0.010795
# 6             6      6_0    COMPLETED  GenerationStep_0  1.246836  -0.034272
# 7             7      7_0    COMPLETED  GenerationStep_0  1.424151  -0.368634
# 8             8      8_0    COMPLETED  GenerationStep_0  0.904074  -2.639563
# 9             9      9_0    COMPLETED  GenerationStep_0  1.605194  -0.884656
# 10           10     10_0    COMPLETED  GenerationStep_0  1.142445  -0.015839
# 11           11     11_0    COMPLETED  GenerationStep_0  1.789892  -0.293677
# 12           12     12_0    COMPLETED  GenerationStep_1  0.794291  -2.025387
# 13           13     13_0    COMPLETED  GenerationStep_1  1.013434  -1.519142
# 14           14     14_0    COMPLETED  GenerationStep_1  1.056580  -1.852645
# 15           15     15_0    COMPLETED  GenerationStep_1  0.959977  -2.314878
# 16           16     16_0    COMPLETED  GenerationStep_1  1.043215  -1.177592
# 17           17     17_0    COMPLETED  GenerationStep_1  0.960728  -1.760926
# 18           18     18_0    COMPLETED  GenerationStep_1  1.057334  -1.840523
# 19           19     19_0    COMPLETED  GenerationStep_1  1.077314  -1.303605
# 20           20     20_0    COMPLETED  GenerationStep_1  0.918555  -2.775542
# 21           21     21_0    COMPLETED  GenerationStep_1  1.177711  -0.003356
# 22           22     22_0    COMPLETED  GenerationStep_1  1.024086  -2.130841
# 23           23     23_0    COMPLETED  GenerationStep_1  1.206596  -1.227124
# 24           24     24_0    COMPLETED  GenerationStep_1  0.871567  -2.483414
#
#               x1            x2        x3        x4        x5        x6
# 0   1.553888e-01  2.400243e-01  0.756256  0.059617  0.785997  0.792401
# 1   6.267743e-01  6.257067e-01  0.205438  0.823240  0.342676  0.153771
# 2   7.896095e-01  2.747037e-01  0.520386  0.391232  0.151348  0.362064
# 3   3.029803e-01  8.556910e-01  0.438317  0.726000  0.719486  0.692252
# 4   4.540908e-01  3.845097e-01  0.020358  0.545190  0.537089  0.983277
# 5   9.513633e-01  9.968766e-01  0.938410  0.337608  0.093509  0.086904
# 6   6.009997e-01  9.887658e-02  0.256167  0.878744  0.402207  0.428999
# 7   1.187874e-01  5.159233e-01  0.705470  0.238430  0.970605  0.501307
# 8   5.880085e-02  3.223445e-01  0.355839  0.259670  0.294152  0.655294
# 9   5.341542e-01  8.119106e-01  0.680020  0.623128  0.835007  0.290132
# 10  8.863795e-01  1.626880e-01  0.123936  0.160606  0.643618  0.194025
# 11  3.959047e-01  7.069340e-01  0.916867  0.956567  0.227702  0.860060
# 12  6.928859e-03  2.413603e-01  0.296439  0.169111  0.221613  0.637972
# 13  4.291098e-18  5.324006e-01  0.499945  0.286442  0.346933  0.539667
# 14  9.875209e-02  9.203104e-02  0.366377  0.293952  0.258735  0.900309
# 15  1.397957e-01  3.903785e-01  0.361119  0.182782  0.343259  0.684087
# 16  0.000000e+00  5.725896e-01  0.340916  0.303688  0.419612  0.613118
# 17  9.496601e-02  3.167988e-01  0.385819  0.488469  0.271201  0.593811
# 18  1.360985e-01  3.223889e-01  0.388958  0.284099  0.205688  0.849228
# 19  0.000000e+00  3.050235e-01  0.211781  0.257297  0.309362  0.927798
# 20  7.741161e-02  1.850234e-15  0.420537  0.265248  0.287024  0.712853
# 21  0.000000e+00  5.134057e-02  0.261627  0.652233  0.943670  0.000000
# 22  5.271926e-01  4.426172e-14  0.323067  0.280836  0.283876  0.712035
# 23  8.417535e-15  6.265316e-01  0.619663  0.261715  0.283496  0.728345
# 24  0.000000e+00  4.699834e-15  0.395342  0.227717  0.284247  0.686062
